# %% [markdown]
# ### 페이지 스크롤바 내리면서 Network에서 어떻게 변하는 지 보고

# %%
import requests

cookies = {
    'NNB': 'WIUTDAXOHAUGO',
    'ASID': 'dc5a6d3200000193be79634300000048',
    'NAC': 'sWE2BYAftrJoA',
    '_fwb': '137YzUI4nHIEUTMJA0X016r.1735173344315',
    'landHomeFlashUseYn': 'Y',
    '_fwb': '137YzUI4nHIEUTMJA0X016r.1735173344315',
    'nhn.realestate.article.rlet_type_cd': 'A01',
    'nhn.realestate.article.trade_type_cd': '""',
    'nhn.realestate.article.ipaddress_city': '4100000000',
    'NACT': '1',
    'SRT30': '1739936597',
    'SRT5': '1739936597',
    'realestate.beta.lastclick.cortar': '1100000000',
    'REALESTATE': 'Wed%20Feb%2019%202025%2012%3A43%3A20%20GMT%2B0900%20(Korean%20Standard%20Time)',
    'BUC': 'bgGRXEQuIzW09AmrYMmCJ-PnrScyXxdI88hert0CnqU=',
}

headers = {
    'accept': '*/*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE3Mzk5MzY2MDAsImV4cCI6MTczOTk0NzQwMH0.UC7jz6bfOpq13HrPjzbkWVXMGKih4JoOh4-xS3opPJo',
    # 'cookie': 'NNB=WIUTDAXOHAUGO; ASID=dc5a6d3200000193be79634300000048; NAC=sWE2BYAftrJoA; _fwb=137YzUI4nHIEUTMJA0X016r.1735173344315; landHomeFlashUseYn=Y; _fwb=137YzUI4nHIEUTMJA0X016r.1735173344315; nhn.realestate.article.rlet_type_cd=A01; nhn.realestate.article.trade_type_cd=""; nhn.realestate.article.ipaddress_city=4100000000; NACT=1; SRT30=1739936597; SRT5=1739936597; realestate.beta.lastclick.cortar=1100000000; REALESTATE=Wed%20Feb%2019%202025%2012%3A43%3A20%20GMT%2B0900%20(Korean%20Standard%20Time); BUC=bgGRXEQuIzW09AmrYMmCJ-PnrScyXxdI88hert0CnqU=',
    'priority': 'u=1, i',
    'referer': 'https://new.land.naver.com/complexes/128640?ms=37.5164145,127.0617151,17&a=APT:PRE:ABYG:JGC&e=RETAIL',
    'sec-ch-ua': '"Not A(Brand";v="8", "Chromium";v="132", "Google Chrome";v="132"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36',
}

response = requests.get(
    'https://new.land.naver.com/api/articles/complex/128640?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=2&complexNo=128640&buildingNos=&areaNos=&type=list&order=rank',
    cookies=cookies,
    headers=headers,
)

# %%
# prompt: response 에서 페이지를 변경해 가면서 매물특징, 가격, 위치 등에 대해, tr의 td를 모두 컬럼으로 해서 데이터프레임으로 변경해줘

import requests
import pandas as pd
from bs4 import BeautifulSoup

# ... (Your existing code for cookies, headers, and the initial request)

def get_real_estate_data(complex_no, num_pages):
    all_data = []
    for page in range(1, num_pages + 1):
        url = f'https://new.land.naver.com/api/articles/complex/{complex_no}?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page={page}&complexNo={complex_no}&buildingNos=&areaNos=&type=list&order=rank'
        response = requests.get(url, cookies=cookies, headers=headers)

        if response.status_code == 200:
            data = response.json()
            if 'articleList' in data and data['articleList']:  # Check for valid data
                for item in data['articleList']:
                    all_data.append(item)
        else:
            print(f"Error fetching page {page}: Status code {response.status_code}")
            # Handle error appropriately (e.g., retry, log)

    return pd.DataFrame(all_data)

# Example usage: fetch data for complex 128640 across 5 pages
df = get_real_estate_data(128640, 5)

# Check if the DataFrame is empty
if not df.empty:
  print(df.head())
else:
  print("DataFrame is empty. Check the API response.")
# Out:
#     articleNo  articleName articleStatus realEstateTypeCode  \
# 0  2505953869  삼성브르넨(주상복합)            R0                APT
# 1  2508943644  삼성브르넨(주상복합)            R0                APT
# 2  2508743246  삼성브르넨(주상복합)            R0                APT
# 3  2508620552  삼성브르넨(주상복합)            R0                APT
# 4  2508591341  삼성브르넨(주상복합)            R0                APT
#
#   realEstateTypeName articleRealEstateTypeCode articleRealEstateTypeName  \
# 0                아파트                       A01                       아파트
# 1                아파트                       A01                       아파트
# 2                아파트                       A01                       아파트
# 3                아파트                       A01                       아파트
# 4                아파트                       A01                       아파트
#
#   tradeTypeCode tradeTypeName verificationTypeCode  ... isLocationShow  \
# 0            B2            월세                 S_VR  ...          False
# ...

# %%
df
# Out:
#      articleNo  articleName articleStatus realEstateTypeCode  \
# 0   2505953869  삼성브르넨(주상복합)            R0                APT
# 1   2508943644  삼성브르넨(주상복합)            R0                APT
# 2   2508743246  삼성브르넨(주상복합)            R0                APT
# 3   2508620552  삼성브르넨(주상복합)            R0                APT
# 4   2508591341  삼성브르넨(주상복합)            R0                APT
# 5   2508042463  삼성브르넨(주상복합)            R0                APT
# 6   2508041292  삼성브르넨(주상복합)            R0                APT
# 7   2508042471  삼성브르넨(주상복합)            R0                APT
# 8   2508016453  삼성브르넨(주상복합)            R0                APT
# 9   2508003748  삼성브르넨(주상복합)            R0                APT
# 10  2508104616  삼성브르넨(주상복합)            R0                APT
# 11  2507468537  삼성브르넨(주상복합)            R0                APT
# 12  2507473165  삼성브르넨(주상복합)            R0                APT
# 13  2508742340  삼성브르넨(주상복합)            R0                APT
# ...

# %% [markdown]
# ### chatGPT에게

# %%
import pandas as pd
# 데이터 저장용 리스트
data_list = []

# 여러 페이지 크롤링 (1~5 페이지 예시)
for page in range(1, 6):
    url = f'https://new.land.naver.com/api/articles/complex/128640?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page={page}&complexNo=128640&buildingNos=&areaNos=&type=list&order=rank'

    response = requests.get(url, cookies=cookies, headers=headers)

    if response.status_code == 200:
        json_data = response.json()
        articles = json_data.get('articleList', [])

        for article in articles:
            data_list.append({
                '매물 ID': article.get('articleNo'),
                '매물명': article.get('articleName'),
                '가격': article.get('price'),
                '보증금': article.get('rentPrice'),
                '월세': article.get('monthlyRent'),
                '면적': article.get('area1'),
                '건물층': article.get('floorInfo'),
                '매물특징': article.get('articleFeatureDesc'),
                '위치': article.get('location'),
                '등록일': article.get('articleConfirmYmd'),
            })
    else:
        print(f"페이지 {page} 크롤링 실패: {response.status_code}")

# DataFrame 생성
df = pd.DataFrame(data_list)
df
# Out:
#          매물 ID          매물명    가격   보증금    월세   면적    건물층  \
# 0   2505953869  삼성브르넨(주상복합)  None  None  None   88   6/20
# 1   2508943644  삼성브르넨(주상복합)  None  None  None  162  18/20
# 2   2508620552  삼성브르넨(주상복합)  None  None  None   56  14/20
# 3   2508743246  삼성브르넨(주상복합)  None  None  None   88   6/20
# 4   2508591341  삼성브르넨(주상복합)  None  None  None   88   6/20
# 5   2508042463  삼성브르넨(주상복합)  None  None  None  162  18/20
# 6   2508104616  삼성브르넨(주상복합)  None  None  None   88   6/20
# 7   2508041292  삼성브르넨(주상복합)  None  None  None   54   5/20
# 8   2508042471  삼성브르넨(주상복합)  None  None  None   56  14/20
# 9   2508016453  삼성브르넨(주상복합)  None  None  None   56  14/20
# 10  2508003748  삼성브르넨(주상복합)  None  None  None   56  14/20
# 11  2507473165  삼성브르넨(주상복합)  None  None  None   56  14/20
# 12  2507468537  삼성브르넨(주상복합)  None  None  None   54   5/20
# 13  2508742340  삼성브르넨(주상복합)  None  None  None   54   저/20
# 14  2508495197  삼성브르넨(주상복합)  None  None  None   56   고/20
# ...

# %%
import requests

cookies = {
    'NNB': 'WIUTDAXOHAUGO',
    'ASID': 'dc5a6d3200000193be79634300000048',
    'NAC': 'sWE2BYAftrJoA',
    '_fwb': '137YzUI4nHIEUTMJA0X016r.1735173344315',
    'landHomeFlashUseYn': 'Y',
    '_fwb': '137YzUI4nHIEUTMJA0X016r.1735173344315',
    'nhn.realestate.article.rlet_type_cd': 'A01',
    'nhn.realestate.article.trade_type_cd': '""',
    'nhn.realestate.article.ipaddress_city': '4100000000',
    'NACT': '1',
    'SRT30': '1739936597',
    'realestate.beta.lastclick.cortar': '1100000000',
    'SRT5': '1739937451',
    'REALESTATE': 'Wed%20Feb%2019%202025%2012%3A58%3A25%20GMT%2B0900%20(Korean%20Standard%20Time)',
    'BUC': '2FXQjw3-Hf_4mo0y0EhDB_pRdb6awnXCA3H2ANMDX7g=',
}

headers = {
    'accept': '*/*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE3Mzk5Mzc1MDUsImV4cCI6MTczOTk0ODMwNX0.EPoXAQcrH1AlN4dkc6A4dzdFvcEQVDiD0eOp8_2lMng',
    # 'cookie': 'NNB=WIUTDAXOHAUGO; ASID=dc5a6d3200000193be79634300000048; NAC=sWE2BYAftrJoA; _fwb=137YzUI4nHIEUTMJA0X016r.1735173344315; landHomeFlashUseYn=Y; _fwb=137YzUI4nHIEUTMJA0X016r.1735173344315; nhn.realestate.article.rlet_type_cd=A01; nhn.realestate.article.trade_type_cd=""; nhn.realestate.article.ipaddress_city=4100000000; NACT=1; SRT30=1739936597; realestate.beta.lastclick.cortar=1100000000; SRT5=1739937451; REALESTATE=Wed%20Feb%2019%202025%2012%3A58%3A25%20GMT%2B0900%20(Korean%20Standard%20Time); BUC=2FXQjw3-Hf_4mo0y0EhDB_pRdb6awnXCA3H2ANMDX7g=',
    'priority': 'u=1, i',
    'referer': 'https://new.land.naver.com/complexes/155817?ms=37.5240492,127.1419781,17&a=APT:PRE:ABYG:JGC&e=RETAIL',
    'sec-ch-ua': '"Not A(Brand";v="8", "Chromium";v="132", "Google Chrome";v="132"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36',
}

response = requests.get(
    'https://new.land.naver.com/api/articles/complex/155817?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=A1&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=2&complexNo=155817&buildingNos=&areaNos=&type=list&order=rank',
    cookies=cookies,
    headers=headers,
)

# %%
import pandas as pd
# 데이터 저장용 리스트
data_list = []

# 여러 페이지 크롤링 (1~5 페이지 예시)
for page in range(1, 6):
    url = f'https://new.land.naver.com/api/articles/complex/155817?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=A1&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=2&complexNo=155817&buildingNos=&areaNos=&type=list&order=rank'

    response = requests.get(url, cookies=cookies, headers=headers)

    if response.status_code == 200:
        json_data = response.json()
        articles = json_data.get('articleList', [])

        for article in articles:
            data_list.append({
                '매물 ID': article.get('articleNo'),
                '매물명': article.get('articleName'),
                '가격': article.get('price'),
                '보증금': article.get('rentPrice'),
                '월세': article.get('monthlyRent'),
                '면적': article.get('area1'),
                '건물층': article.get('floorInfo'),
                '매물특징': article.get('articleFeatureDesc'),
                '위치': article.get('location'),
                '등록일': article.get('articleConfirmYmd'),
            })
    else:
        print(f"페이지 {page} 크롤링 실패: {response.status_code}")

# DataFrame 생성
df = pd.DataFrame(data_list)
df
# Out:
#          매물 ID       매물명    가격   보증금    월세   면적    건물층  \
# 0   2508905451  올림픽파크포레온  None  None  None  144  20/35
# 1   2508893297  올림픽파크포레온  None  None  None  112   9/35
# 2   2508655314  올림픽파크포레온  None  None  None  112   9/35
# 3   2508673133  올림픽파크포레온  None  None  None  144  20/35
# 4   2508673788  올림픽파크포레온  None  None  None  142  15/35
# ..         ...       ...   ...   ...   ...  ...    ...
# 95  2508529333  올림픽파크포레온  None  None  None  142  15/35
# 96  2508364572  올림픽파크포레온  None  None  None  144  20/35
# 97  2508761375  올림픽파크포레온  None  None  None  144  24/35
# 98  2508358529  올림픽파크포레온  None  None  None  142  15/35
# 99  2508331423  올림픽파크포레온  None  None  None  144  24/35
#
#                                       매물특징    위치       등록일
# 0               43 예쁜단지 트인뷰 동간거리확보 남향 갭투가능  None  20250219
# 1         34D 남향 동간거리넓은동 전망굿 종합스포츠센타인근 위례초  None  20250219
# 2            34D 남향 굿뷰 종합스포츠센타인근 위례초 동간거리굿  None  20250218
# 3    43 확트인뷰 주인직접 조합원 초기투자금 10억 입주시잔금 조정가능  None  20250218
# ...
