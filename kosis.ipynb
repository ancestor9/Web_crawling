# %%
# 인증키 발급받기

# %%
url ='https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=OWZkNzNhMDBjMTRhYjk5NTk0ZDg5NWU4NmVkYjVhOTE=&itmId=T100+T110+T120+T130+T131+T132+T140+T141+T142+T200+T210+T220+T230+T310+T311+T312+T313+T314+T315+T320+&objL1=...&objL2=&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=Y&newEstPrdCnt=3&orgId=101&tblId=DT_1IN1502'

# %%
import requests

response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.text)  # Raise an exception for bad status codes
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# prompt: [
#   {
#     "C1_OBJ_NM": "행정구역별(읍면동)",
#     "DT": "51738071",
#     "C1": "00",
#     "PRD_SE": "A",
#     "UNIT_NM_ENG": "Person",
#     "ITM_ID": "T100",
#     "TBL_ID": "DT_1IN1502",
#     "ITM_NM": "총인구",
#     "TBL_NM": "인구 가구 및 주택 – 읍면동(연도 끝자리 0 5) 시군구(그 외 연도)",
#     "PRD_DE": "2021",
#     "LST_CHN_DE": "2022-07-18",
#     "C1_NM_ENG": "Whole country",
#     "C1_NM": "전국",
#     "UNIT_NM": "명",
#     "ITM_NM_ENG": "Total population",
#     "ORG_ID": "101",
#     "C1_OBJ_NM_ENG": "By administrative divisions(eup myeon dong)"
#   },
#   {
#     "C1_OBJ_NM": "행정구역별(읍면동)",
#     "DT": "51692272",
#     "C1": "00",
#     "PRD_SE": "A",
#     "UNIT_NM_ENG": "Person",
#     "ITM_ID": "T100",
#     "TBL_ID": "DT_1IN1502",
#     "ITM_NM": "총인구",
#     "TBL_NM": "인구 가구 및 주택 – 읍면동(연도 끝자리 0 5) 시군구(그 외 연도)",
#     "PRD_DE": "2022",
#     "LST_CHN_DE": "2024-07-03",
#     "C1_NM_ENG": "Whole country",
#     "C1_NM": "전국",
#     "UNIT_NM": "명",
#     "ITM_NM_ENG": "Total population",
#     "ORG_ID": "101",
#     "C1_OBJ_NM_ENG": "By administrative divisions(eup myeon dong)"
#   },.....]
# 이 자료의 사전형자료만 데이터프레임으로 변경해줘

```python
import requests
import pandas as pd

# 인증키 발급받기
url ='https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=OWZkNzNhMDBjMTRhYjk5NTk0ZDg5NWU4NmVkYjVhOTE=&itmId=T100+T110+T120+T130+T131+T132+T140+T141+T142+T200+T210+T220+T230+T310+T311+T312+T313+T314+T315+T320+&objL1=...
