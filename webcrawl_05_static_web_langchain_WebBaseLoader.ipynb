# %%
# %%capture
# !pip install langchain-community

# %%
import bs4
from langchain_community.document_loaders import WebBaseLoader

# 여러 개의 url 지정 가능
url1 = "https://blog.langchain.dev/customers-replit/"
url2 = "https://blog.langchain.dev/langgraph-v0-2/"

loader = WebBaseLoader(
    web_paths=(url1, url2),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("article-header", "article-content")
        )
    ),
)
docs = loader.load()
len(docs)
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.
# 2

# %% [markdown]
# - 브라우저처럼 보이도록 User-Agent 값을 설정.
# - 일부 사이트는 자동화된 스크래핑을 차단하지만, 브라우저 요청처럼 보이면 정상적으로 데이터를 가져올 수 있음.
# - 웹 서버가 "이 요청은 사람이 보낸 것"이라고 인식하도록 함.

# %%
# 여러 개의 URL 지정 가능
url1 = "https://blog.langchain.dev/customers-replit/"
url2 = "https://blog.langchain.dev/langgraph-v0-2/"


# 사용자 User-Agent 설정
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36"

# WebBaseLoader에 User-Agent 추가
loader = WebBaseLoader(
    web_paths=(url1, url2),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("article-header",         # article-header : (기사 제목 부분)
                    "article-content")        # article-content" (본문 내용 부분)
        )
    ),
    requests_kwargs={
        "headers": {
            "User-Agent": user_agent
        }
    }
)

docs = loader.load()
print(f"로드된 문서 개수: {len(docs)}")
# Out:
# 로드된 문서 개수: 2

# %%
len(docs)
# Out:
# 2

# %%
docs[0]
# Out:
# Document(metadata={'source': 'https://blog.langchain.dev/customers-replit/'}, page_content='\nReplit is at the forefront of AI innovation with its platform that simplifies writing, running, and collaborating on code for over 30+ million developers. They recently released Replit Agent, which immediately went viral due to the incredible applications people could easily create with this tool.Behind the scenes, Replit Agent has a complex workflow built on LangGraph, which enables a highly custom agentic workflow with a high-degree of control and parallel execution. A major benefit of using LangGraph was the seamless integration with LangSmith, which gave Replit deep visibility into their agent interactions to debug tricky issues.\xa0The level of complexity required for Replit Agent also pushed the boundaries of LangSmith. The LangChain and Replit teams worked closely together to add functionality to LangSmith that would satisfy their LLM observability needs. Specifically, there were three main areas that we innovated on:Improved performance and scale on large tracesAbility to search and filter within tracesThread view to enable human-in-the loop workflowsImproved performance and scale on large tracesMost other LLMOps solutions monitor individual API requests to LLM providers, offering a limited view of single LLM calls. In contrast, LangSmith from day one has focused on tracing the entire execution flow of an LLM application to provide a more holistic context.\xa0Tracing is important for agents due to their complex nature. It captures multiple LLM calls as well as other steps (retrieval, running code, etc). This gives you granular visibility into what’s happening, including at the inputs and outputs of each step, in order to understand the agent’s decision-making.\xa0Replit Agent was a ripe example for advanced tracing needs. Their agentic tool goes beyond simply reviewing and writing code, but also performs a wider range of functions – including planning, creating dev environments, installing dependencies, and deploying applications for users.\xa0As a result, Replit’s traces were very large - involving hundreds of steps. This posed significant challenges for ingesting data and displaying it in a visually meaningful way.To address this, the LangChain team improved their ingestion to efficiently process and store large volumes of trace data. They also improved LangSmith’s frontend rendering to display long-running agent traces seamlessly.Search and filter within traces to pinpoint issuesLangSmith has always supported search between traces, which allows users to find a single trace among hundreds of thousands based on events or full text search. But as Replit Agent’s traces got longer and longer, the Replit team needed to search within traces for specific events (oftentimes issues reported by alpha testers). This required augmenting existing search capabilities.In response, a new search pattern – searching within traces – was added to LangSmith. Instead of sifting and scrolling call-by-call within a large trace, users could now filter directly on a criteria they cared about (e.g. keywords in the inputs or outputs of a run). This greatly reduced Replit’s time needed to debug agent steps within a trace.Thread view to enable human-in-the-loop workflowsA key differentiator of Replit Agent was its emphasis on human-in-the-loop workflows. Replit Agent intends to be a tool where AI agents can collaborate effectively with human developers, who can come in and edit and correct agent trajectories as needed.With separate agents to perform roles like managing, editing, and verifying generated code,\xa0 Replit’s agents interacted with users continuously - often over long periods with multiple turns of conversation. However, monitoring these conversational flows was often difficult, as each user session would generate disjoint traces.\xa0To solve this, LangSmith’s thread view helped collate traces from multiple threads together that were related  ...

# %%
docs[1]
# Out:
# Document(metadata={'source': 'https://blog.langchain.dev/langgraph-v0-2/'}, page_content="\nToday, we’re excited to announce the stable release of LangGraph v0.2, which introduces a new ecosystem of LangGraph checkpointer libraries. These simplify the creation and customization of checkpointers, which allows users to build more resilient LLM applications with smooth session memory, robust error recovery, and human-in-the-loop features.Why we built LangGraph v0.2One of the key pillars of LangGraph is its built-in persistence layer, implemented through checkpointers. When you use a checkpointer with a graph, you can interact with and manage the graph's state. The checkpointer saves a checkpoint of the graph state at each step, enabling several powerful capabilities, including:Session memory: Store history (checkpoints) of user interactions and resume from a saved checkpoint in follow up interactionsError recovery: Recover from failures at any given step in the graph execution by continuing from the last successful step checkpointHuman-in-the-loop: Implement tool approval, wait for human input, edit agent actions and moreTime travel: Edit graph state at any point in the history of execution and create an alternative execution from that point in time (i.e. fork the thread)Since the early days of LangGraph, we’ve designed checkpointing to be database-agnostic, allowing users to implement their own checkpointer adapters for their database of choice.Since the LangGraph v0.1 release, we've seen a lot of interest from the community in creating checkpointers for many popular databases like Postgres, Redis, and MongoDB. However, there was no clear blueprint for the users to implement their own, custom checkpointers.New checkpointer libraries in LangGraphWith LangGraph v0.2, we’re making it easier to create new checkpointers. We’ve also laid the foundation to foster a community-maintained ecosystem of checkpointer implementations.We now have a suite of new, dedicated checkpointer libraries:langgraph_checkpoint : The base interface for checkpointer savers (BaseCheckpointSaver ) and serialization/deserialization interface (SerializationProtocol). Includes in-memory checkpointer implementation (MemorySaver) for experimentation.langgraph_checkpoint_sqlite : An implementation of LangGraph checkpointer that uses SQLite database. Ideal for experimentation and local workflows.langgraph_checkpoint_postgres : Our advanced checkpointer that we wrote and optimized for Postgres in LangGraph Cloud is now open-sourced and available to the community to build upon. Ideal for using in production.Checkpointer implementations can be used interchangeably, which lets users tailor their stateful LangGraph applications to their custom needs.LangGraph Postgres Checkpointer for production-ready appslanggraph_checkpoint_postgres implementation can serve as a blueprint for community members to implement their own optimized, production-ready checkpointers for their favorite database. Postgres checkpointer implements a number of optimizations both on the write-, as well as read-side.Write-side optimizations:We're making use of Postgres pipeline mode to reduce database roundtripsWe're storing each channel value separately and versioned so that each new checkpoint only stores the values that changed.Read-side optimizations:We're making use of a cursor for the list endpoint in order to efficiently fetch long thread histories when needed.Getting started on LangGraph v0.2Since LangGraph checkpointer libraries are implemented as namespace packages, you can import checkpointer interfaces and implementations the same way as before, using:from langgraph.checkpoint.base import BaseCheckpointSaverfrom langgraph.checkpoint.memory import MemorySaverfrom langgraph.checkpoint.sqlite import SqliteSaverfrom langgraph.checkpoint.postgres import PostgresSaverSince SQLite and Postgres checkpointers are provided via separate libraries, you will need to install them using pip install langg ...

# %%
f'https://startcoding.pythonanywhere.com/basic?page=1'
# Out:
# 'https://startcoding.pythonanywhere.com/basic?page=1'

# %%
[f'https://startcoding.pythonanywhere.com/basic?page={i}' for i in range(1,5)]
# Out:
# ['https://startcoding.pythonanywhere.com/basic?page=1',
#  'https://startcoding.pythonanywhere.com/basic?page=2',
#  'https://startcoding.pythonanywhere.com/basic?page=3',
#  'https://startcoding.pythonanywhere.com/basic?page=4']

# %% [markdown]
# ### 구글에서 검색어 검색하고 기사를 스크래핑

# %%
from google.colab import userdata
YOUR_SERPAPI_KEY = userdata.get('serpapi')
print(YOUR_SERPAPI_KEY[:10])
# Out:
# 4eee03a51b

# %%
# %%capture
# !pip install google-search-results

# %%
from serpapi import GoogleSearch
from langchain_community.document_loaders import WebBaseLoader
import bs4

# SerpAPI 키 설정
SERPAPI_API_KEY = YOUR_SERPAPI_KEY  # 여기에 네 키 입력해줘

# 검색어 목록
queries = ["LangChain", "ChatGPT plugins", "AI agents", "RAG pipeline", "LLM orchestration"]

# 기사 URL 저장 리스트
article_urls = []

# 검색어마다 뉴스 기사 URL 1개씩 추출
for query in queries:
    params = {
        "engine": "google",
        "q": query,
        "tbm": "nws",  # 뉴스 검색
        "api_key": SERPAPI_API_KEY,
        "num": 2
    }
    search = GoogleSearch(params)

    results = search.get_dict()
    print(f"SerpAPI results: {results}")  # Print the raw response
    news_results = results.get("news_results", [])

    for result in news_results[:1]:  # 검색어당 기사 1개씩만 가져오기
        link = result.get("link")
        if link:
            article_urls.append(link)

# WebBaseLoader로 기사 로드
loader = WebBaseLoader(
    web_paths=article_urls,
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(name=["article", "main", "div"], class_=True)
    ),
    requests_kwargs={
        "headers": {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36"
        }
    }
)

docs = loader.load()
print(f"가져온 기사 수: {len(docs)}")
for i, doc in enumerate(docs, 1):
    print(f"\n--- [Article {i}] ---")
    print(doc.page_content[:300])  # 본문 일부 미리보기
# Out:
# SerpAPI results: {'search_metadata': {'id': '67dcc7ab8d7b2a72e0e32642', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/cf55c49dcd3f1d59/67dcc7ab8d7b2a72e0e32642.json', 'created_at': '2025-03-21 01:58:03 UTC', 'processed_at': '2025-03-21 01:58:03 UTC', 'google_url': 'https://www.google.com/search?q=LangChain&oq=LangChain&num=2&tbm=nws&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/cf55c49dcd3f1d59/67dcc7ab8d7b2a72e0e32642.html', 'total_time_taken': 3.03}, 'search_parameters': {'engine': 'google', 'q': 'LangChain', 'google_domain': 'google.com', 'num': '2', 'device': 'desktop', 'tbm': 'nws'}, 'search_information': {'query_displayed': 'LangChain', 'total_results': 588, 'time_taken_displayed': 0.2, 'news_results_state': 'Results for exact spelling'}, 'news_results': [{'position': 1, 'link': 'https://www.prnewswire.com/news-releases/qualtrics-and-langchain-announce-partnership-to-develop-highly-specialized-experience-agents-302405449.html', 'title': 'Qualtrics and LangChain Announce Partnership to Develop Highly Specialized Experience Agents', 'source': 'PR Newswire', 'date': '1 day ago', 'snippet': 'PRNewswire/ -- Qualtrics, the leader and creator of the experience management category, and LangChain, a leading platform for building and...', 'thumbnail': 'https://serpapi.com/searches/67dcc7ab8d7b2a72e0e32642/images/7d914fd0dcb64376c526cbc546a2637e25c34cae35d9722b4a7549cfc1d35861.jpeg'}, {'position': 2, 'link': 'https://aws.amazon.com/blogs/dotnet/building-context-aware-generative-ai-chatbot-using-amazon-bedrock-and-langchain-in-net/', 'title': 'Build a .NET Context-Aware Generative AI Chatbot using Amazon Bedrock and LangChain', 'source': 'Amazon Web Services (AWS)', 'date': '3 days ago', 'snippet': 'Generative AI is taking chatbots to the next level by empowering them to engage in human-like dialogues. These advanced conversational...', 'thumbnail': 'https://serpapi.com/searches/67dcc7ab8d7b2a72e0e32642/images/7d914fd0dcb64376b0e989844d3a4576e47aa46323247ac4c9332dd27a85d1d4.jpeg'}], 'pagination': {'current': 1, 'next': 'https://www.google.com/search?q=LangChain&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ-uAAvmD9u8P3dXCsAQ&start=2&sa=N&ved=2ahUKEwjrj_2uiZqMAxX5gf0HHd2qEEYQ8NMDegQIBRAW', 'other_pages': {'2': 'https://www.google.com/search?q=LangChain&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ-uAAvmD9u8P3dXCsAQ&start=2&sa=N&ved=2ahUKEwjrj_2uiZqMAxX5gf0HHd2qEEYQ8tMDegQIBRAE', '3': 'https://www.google.com/search?q=LangChain&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ-uAAvmD9u8P3dXCsAQ&start=4&sa=N&ved=2ahUKEwjrj_2uiZqMAxX5gf0HHd2qEEYQ8tMDegQIBRAG', '4': 'https://www.google.com/search?q=LangChain&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ-uAAvmD9u8P3dXCsAQ&start=6&sa=N&ved=2ahUKEwjrj_2uiZqMAxX5gf0HHd2qEEYQ8tMDegQIBRAI', '5': 'https://www.google.com/search?q=LangChain&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ-uAAvmD9u8P3dXCsAQ&start=8&sa=N&ved=2ahUKEwjrj_2uiZqMAxX5gf0HHd2qEEYQ8tMDegQIBRAK', '6': 'https://www.google.com/search?q=LangChain&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ-uAAvmD9u8P3dXCsAQ&start=10&sa=N&ved=2ahUKEwjrj_2uiZqMAxX5gf0HHd2qEEYQ8tMDegQIBRAM', '7': 'https://www.google.com/search?q=LangChain&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ-uAAvmD9u8P3dXCsAQ&start=12&sa=N&ved=2ahUKEwjrj_2uiZqMAxX5gf0HHd2qEEYQ8tMDegQIBRAO', '8': 'https://www.google.com/search?q=LangChain&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ-uAAvmD9u8P3dXCsAQ&start=14&sa=N&ved=2ahUKEwjrj_2uiZqMAxX5gf0HHd2qEEYQ8tMDegQIBRAQ', '9': 'https://www.google.com/search?q=LangChain&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ-uAAvmD9u8P3dXCsAQ&start=16&sa=N&ved=2ahUKEwjrj_2uiZqMAxX5gf0HHd2qEEYQ8tMDegQIBRAS', '10': 'https://www.google.com/search?q=LangChain&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ-uAAvmD9u8P3dXCsAQ&start=18&sa=N&ved=2ahUKEwjrj_2uiZqMAxX5gf0HHd2qEEYQ8tMDegQIBRAU'}}, 'serpapi_pagination': {'current': 1, 'next_link': 'https://serpapi.com/search.json?device=de ...
# SerpAPI results: {'search_metadata': {'id': '67dcc7ae75d080784bac2612', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/04c34b44ba90cb0a/67dcc7ae75d080784bac2612.json', 'created_at': '2025-03-21 01:58:06 UTC', 'processed_at': '2025-03-21 01:58:06 UTC', 'google_url': 'https://www.google.com/search?q=ChatGPT+plugins&oq=ChatGPT+plugins&num=2&tbm=nws&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/04c34b44ba90cb0a/67dcc7ae75d080784bac2612.html', 'total_time_taken': 0.36}, 'search_parameters': {'engine': 'google', 'q': 'ChatGPT plugins', 'google_domain': 'google.com', 'num': '2', 'device': 'desktop', 'tbm': 'nws'}, 'search_information': {'query_displayed': 'ChatGPT plugins', 'total_results': 1280, 'time_taken_displayed': 0.25, 'news_results_state': 'Results for exact spelling'}, 'news_results': [{'position': 1, 'link': 'https://themeisle.com/blog/build-a-wordpress-plugin-with-chatgpt/', 'title': 'My Journey to Creating a WordPress Plugin With ChatGPT: 120 Hours of Work, No Prior Experience', 'source': 'Themeisle', 'date': 'Aug 28, 2024', 'snippet': "120 hours' worth of details, to be exact. Yes, that's how long it actually took me to build the plugin from start to finish: 120 hours!", 'thumbnail': 'https://serpapi.com/searches/67dcc7ae75d080784bac2612/images/1475d9fa0b50683563d7ea77dbd7bee0d5708d4a2dde92877008ed6a297da4ca.jpeg'}, {'position': 2, 'link': 'https://www.techtarget.com/searchsecurity/tip/ChatGPT-plugin-flaws-introduce-enterprise-security-risks', 'title': 'ChatGPT plugin flaws introduce enterprise security risks', 'source': 'TechTarget', 'date': 'Jun 4, 2024', 'snippet': "ChatGPT plugins could potentially create new vulnerabilities within an enterprise's IT ecosystem and increase susceptibility to cyberattacks,...", 'thumbnail': 'https://serpapi.com/searches/67dcc7ae75d080784bac2612/images/1475d9fa0b506835372463d541a19aed53b9bcb4d2d28edb007aae51b351b5af.jpeg'}], 'pagination': {'current': 1, 'next': 'https://www.google.com/search?q=ChatGPT+plugins&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ9HDMvyn5NoPpvPZ6QE&start=2&sa=N&ved=2ahUKEwjR0q2viZqMAxX8E1kFHaZ5Nh0Q8NMDegQIBRAW', 'other_pages': {'2': 'https://www.google.com/search?q=ChatGPT+plugins&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ9HDMvyn5NoPpvPZ6QE&start=2&sa=N&ved=2ahUKEwjR0q2viZqMAxX8E1kFHaZ5Nh0Q8tMDegQIBRAE', '3': 'https://www.google.com/search?q=ChatGPT+plugins&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ9HDMvyn5NoPpvPZ6QE&start=4&sa=N&ved=2ahUKEwjR0q2viZqMAxX8E1kFHaZ5Nh0Q8tMDegQIBRAG', '4': 'https://www.google.com/search?q=ChatGPT+plugins&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ9HDMvyn5NoPpvPZ6QE&start=6&sa=N&ved=2ahUKEwjR0q2viZqMAxX8E1kFHaZ5Nh0Q8tMDegQIBRAI', '5': 'https://www.google.com/search?q=ChatGPT+plugins&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ9HDMvyn5NoPpvPZ6QE&start=8&sa=N&ved=2ahUKEwjR0q2viZqMAxX8E1kFHaZ5Nh0Q8tMDegQIBRAK', '6': 'https://www.google.com/search?q=ChatGPT+plugins&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ9HDMvyn5NoPpvPZ6QE&start=10&sa=N&ved=2ahUKEwjR0q2viZqMAxX8E1kFHaZ5Nh0Q8tMDegQIBRAM', '7': 'https://www.google.com/search?q=ChatGPT+plugins&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ9HDMvyn5NoPpvPZ6QE&start=12&sa=N&ved=2ahUKEwjR0q2viZqMAxX8E1kFHaZ5Nh0Q8tMDegQIBRAO', '8': 'https://www.google.com/search?q=ChatGPT+plugins&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ9HDMvyn5NoPpvPZ6QE&start=14&sa=N&ved=2ahUKEwjR0q2viZqMAxX8E1kFHaZ5Nh0Q8tMDegQIBRAQ', '9': 'https://www.google.com/search?q=ChatGPT+plugins&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ9HDMvyn5NoPpvPZ6QE&start=16&sa=N&ved=2ahUKEwjR0q2viZqMAxX8E1kFHaZ5Nh0Q8tMDegQIBRAS', '10': 'https://www.google.com/search?q=ChatGPT+plugins&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=rsfcZ9HDMvyn5NoPpvPZ6QE&start=18&sa=N&ved=2ahUKEwjR0q2viZqMAxX8E1kFHaZ5Nh0Q8tMDegQIBRAU'}}, 'serpapi_pagination': {'current': 1, 'next_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&num=2&q=Ch ...
# SerpAPI results: {'search_metadata': {'id': '67dcc7afb840a59f0337ad1f', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/f18cca1d197dbc16/67dcc7afb840a59f0337ad1f.json', 'created_at': '2025-03-21 01:58:07 UTC', 'processed_at': '2025-03-21 01:58:07 UTC', 'google_url': 'https://www.google.com/search?q=AI+agents&oq=AI+agents&num=2&tbm=nws&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/f18cca1d197dbc16/67dcc7afb840a59f0337ad1f.html', 'total_time_taken': 0.63}, 'search_parameters': {'engine': 'google', 'q': 'AI agents', 'google_domain': 'google.com', 'num': '2', 'device': 'desktop', 'tbm': 'nws'}, 'search_information': {'query_displayed': 'AI agents', 'total_results': 248000, 'time_taken_displayed': 0.24, 'news_results_state': 'Results for exact spelling'}, 'news_results': [{'position': 1, 'link': 'https://www.barrons.com/articles/alphabet-stock-ai-agents-6a0e87cd', 'title': 'Alphabet Is ‘Best Positioned,’ for the AI Agent Era, Analyst Says', 'source': "Barron's", 'date': '9 hours ago', 'snippet': 'Stifel analyst Mark Kelley said people paying for subscriptions to AI agents are less likely to use traditional search.', 'thumbnail': 'https://serpapi.com/searches/67dcc7afb840a59f0337ad1f/images/068142816548ccab14db02af630e80c69017b1bb2d4c512f370aefb3a9811dd3.jpeg'}, {'position': 2, 'link': 'https://www.oracle.com/news/announcement/oracle-introduces-ai-agent-studio-2025-03-20/', 'title': 'Oracle Introduces AI Agent Studio', 'source': 'Oracle', 'date': '17 hours ago', 'snippet': 'New Oracle AI Agent Studio empowers Oracle Fusion Cloud Applications customers and partners to easily create, extend, deploy, and manage AI...', 'thumbnail': 'https://serpapi.com/searches/67dcc7afb840a59f0337ad1f/images/068142816548ccab53010239c5383c5a06afdba602320426965878a6d1ec5e48.jpeg'}], 'pagination': {'current': 1, 'next': 'https://www.google.com/search?q=AI+agents&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=r8fcZ6mfH5rPxc8P6da-8QQ&start=2&sa=N&ved=2ahUKEwjpsteviZqMAxWaZ_EDHWmrL04Q8NMDegQIBRAW', 'other_pages': {'2': 'https://www.google.com/search?q=AI+agents&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=r8fcZ6mfH5rPxc8P6da-8QQ&start=2&sa=N&ved=2ahUKEwjpsteviZqMAxWaZ_EDHWmrL04Q8tMDegQIBRAE', '3': 'https://www.google.com/search?q=AI+agents&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=r8fcZ6mfH5rPxc8P6da-8QQ&start=4&sa=N&ved=2ahUKEwjpsteviZqMAxWaZ_EDHWmrL04Q8tMDegQIBRAG', '4': 'https://www.google.com/search?q=AI+agents&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=r8fcZ6mfH5rPxc8P6da-8QQ&start=6&sa=N&ved=2ahUKEwjpsteviZqMAxWaZ_EDHWmrL04Q8tMDegQIBRAI', '5': 'https://www.google.com/search?q=AI+agents&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=r8fcZ6mfH5rPxc8P6da-8QQ&start=8&sa=N&ved=2ahUKEwjpsteviZqMAxWaZ_EDHWmrL04Q8tMDegQIBRAK', '6': 'https://www.google.com/search?q=AI+agents&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=r8fcZ6mfH5rPxc8P6da-8QQ&start=10&sa=N&ved=2ahUKEwjpsteviZqMAxWaZ_EDHWmrL04Q8tMDegQIBRAM', '7': 'https://www.google.com/search?q=AI+agents&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=r8fcZ6mfH5rPxc8P6da-8QQ&start=12&sa=N&ved=2ahUKEwjpsteviZqMAxWaZ_EDHWmrL04Q8tMDegQIBRAO', '8': 'https://www.google.com/search?q=AI+agents&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=r8fcZ6mfH5rPxc8P6da-8QQ&start=14&sa=N&ved=2ahUKEwjpsteviZqMAxWaZ_EDHWmrL04Q8tMDegQIBRAQ', '9': 'https://www.google.com/search?q=AI+agents&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=r8fcZ6mfH5rPxc8P6da-8QQ&start=16&sa=N&ved=2ahUKEwjpsteviZqMAxWaZ_EDHWmrL04Q8tMDegQIBRAS', '10': 'https://www.google.com/search?q=AI+agents&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=r8fcZ6mfH5rPxc8P6da-8QQ&start=18&sa=N&ved=2ahUKEwjpsteviZqMAxWaZ_EDHWmrL04Q8tMDegQIBRAU'}}, 'serpapi_pagination': {'current': 1, 'next_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&num=2&q=AI+agents&start=2&tbm=nws', 'next': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&num=2&q=AI+agents&start=2&tbm=nws', 'other_pages':  ...
# SerpAPI results: {'search_metadata': {'id': '67dcc7b095dc12e693bfe9a6', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/25e507373751b0da/67dcc7b095dc12e693bfe9a6.json', 'created_at': '2025-03-21 01:58:08 UTC', 'processed_at': '2025-03-21 01:58:08 UTC', 'google_url': 'https://www.google.com/search?q=RAG+pipeline&oq=RAG+pipeline&num=2&tbm=nws&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/25e507373751b0da/67dcc7b095dc12e693bfe9a6.html', 'total_time_taken': 0.9}, 'search_parameters': {'engine': 'google', 'q': 'RAG pipeline', 'google_domain': 'google.com', 'num': '2', 'device': 'desktop', 'tbm': 'nws'}, 'search_information': {'query_displayed': 'RAG pipeline', 'total_results': 372, 'time_taken_displayed': 0.2, 'news_results_state': 'Results for exact spelling'}, 'news_results': [{'position': 1, 'link': 'https://blogs.nvidia.com/blog/what-is-retrieval-augmented-generation/', 'title': 'What Is Retrieval-Augmented Generation, aka RAG?', 'source': 'NVIDIA Blog', 'date': '1 month ago', 'snippet': 'Retrieval-augmented generation (RAG) is a technique for enhancing the accuracy and reliability of generative AI models with facts fetched...', 'thumbnail': 'https://serpapi.com/searches/67dcc7b095dc12e693bfe9a6/images/00962c568bdf3202adab3dd1c47ee7915764a1786c10ba8c40186c4bd013df6d.jpeg'}, {'position': 2, 'link': 'https://aws.amazon.com/blogs/security/securing-the-rag-ingestion-pipeline-filtering-mechanisms/', 'title': 'Securing the RAG ingestion pipeline: Filtering mechanisms | Amazon Web Services', 'source': 'Amazon Web Services', 'date': 'Nov 19, 2024', 'snippet': 'In this post, we explore some of the potential security risks of ingesting external data or documents into the knowledge base of your RAG application.', 'thumbnail': 'https://serpapi.com/searches/67dcc7b095dc12e693bfe9a6/images/00962c568bdf3202877f7727f1d0ef767c89d578589dafa45591d252b9f0c332.png'}], 'pagination': {'current': 1, 'next': 'https://www.google.com/search?q=RAG+pipeline&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=sMfcZ56-JK3Z1e8PyOL8wAU&start=2&sa=N&ved=2ahUKEwie1pmwiZqMAxWtbPUHHUgxH1gQ8NMDegQIBRAW', 'other_pages': {'2': 'https://www.google.com/search?q=RAG+pipeline&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=sMfcZ56-JK3Z1e8PyOL8wAU&start=2&sa=N&ved=2ahUKEwie1pmwiZqMAxWtbPUHHUgxH1gQ8tMDegQIBRAE', '3': 'https://www.google.com/search?q=RAG+pipeline&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=sMfcZ56-JK3Z1e8PyOL8wAU&start=4&sa=N&ved=2ahUKEwie1pmwiZqMAxWtbPUHHUgxH1gQ8tMDegQIBRAG', '4': 'https://www.google.com/search?q=RAG+pipeline&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=sMfcZ56-JK3Z1e8PyOL8wAU&start=6&sa=N&ved=2ahUKEwie1pmwiZqMAxWtbPUHHUgxH1gQ8tMDegQIBRAI', '5': 'https://www.google.com/search?q=RAG+pipeline&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=sMfcZ56-JK3Z1e8PyOL8wAU&start=8&sa=N&ved=2ahUKEwie1pmwiZqMAxWtbPUHHUgxH1gQ8tMDegQIBRAK', '6': 'https://www.google.com/search?q=RAG+pipeline&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=sMfcZ56-JK3Z1e8PyOL8wAU&start=10&sa=N&ved=2ahUKEwie1pmwiZqMAxWtbPUHHUgxH1gQ8tMDegQIBRAM', '7': 'https://www.google.com/search?q=RAG+pipeline&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=sMfcZ56-JK3Z1e8PyOL8wAU&start=12&sa=N&ved=2ahUKEwie1pmwiZqMAxWtbPUHHUgxH1gQ8tMDegQIBRAO', '8': 'https://www.google.com/search?q=RAG+pipeline&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=sMfcZ56-JK3Z1e8PyOL8wAU&start=14&sa=N&ved=2ahUKEwie1pmwiZqMAxWtbPUHHUgxH1gQ8tMDegQIBRAQ', '9': 'https://www.google.com/search?q=RAG+pipeline&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=sMfcZ56-JK3Z1e8PyOL8wAU&start=16&sa=N&ved=2ahUKEwie1pmwiZqMAxWtbPUHHUgxH1gQ8tMDegQIBRAS', '10': 'https://www.google.com/search?q=RAG+pipeline&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=sMfcZ56-JK3Z1e8PyOL8wAU&start=18&sa=N&ved=2ahUKEwie1pmwiZqMAxWtbPUHHUgxH1gQ8tMDegQIBRAU'}}, 'serpapi_pagination': {'current': 1, 'next_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&num=2&q=RAG+pipeline&start=2&tbm=nws', 'next': 'https://serp ...
# SerpAPI results: {'search_metadata': {'id': '67dcc7b1c88727eac3b9b440', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/92ad5b9c26a13f3f/67dcc7b1c88727eac3b9b440.json', 'created_at': '2025-03-21 01:58:09 UTC', 'processed_at': '2025-03-21 01:58:09 UTC', 'google_url': 'https://www.google.com/search?q=LLM+orchestration&oq=LLM+orchestration&num=2&tbm=nws&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/92ad5b9c26a13f3f/67dcc7b1c88727eac3b9b440.html', 'total_time_taken': 5.82}, 'search_parameters': {'engine': 'google', 'q': 'LLM orchestration', 'google_domain': 'google.com', 'num': '2', 'device': 'desktop', 'tbm': 'nws'}, 'search_information': {'query_displayed': 'LLM orchestration', 'total_results': 104, 'time_taken_displayed': 0.2, 'news_results_state': 'Results for exact spelling'}, 'news_results': [{'position': 1, 'link': 'https://venturebeat.com/ai/octotools-stanfords-open-source-framework-optimizes-llm-reasoning-through-modular-tool-orchestration/', 'title': "OctoTools: Stanford's open-source framework optimizes LLM reasoning through modular tool orchestration", 'source': 'VentureBeat', 'date': '3 weeks ago', 'snippet': 'OctoTools, a new open-source agentic platform released by scientists at Stanford University, can turbocharge large language models (LLMs) for...', 'thumbnail': 'https://serpapi.com/searches/67dcc7b1c88727eac3b9b440/images/6d4a318a260e88ef7eab70171a4edad2b3f37c33f06c92e645bbe876531d62bc.jpeg'}, {'position': 2, 'link': 'https://www.infoworld.com/article/3835182/portkey-an-open-source-ai-gateway-for-easy-llm-orchestration.html', 'title': 'Portkey: An open-source AI gateway for easy LLM orchestration', 'source': 'InfoWorld', 'date': '2 weeks ago', 'snippet': 'Portkey AI Gateway is an open-source library that simplifies LLM integration for Python developers. It provides a robust framework with a...', 'thumbnail': 'https://serpapi.com/searches/67dcc7b1c88727eac3b9b440/images/6d4a318a260e88efd56241bdd6ed1060631f12b3de5fd4dec807d05b33e2fc60.jpeg'}], 'pagination': {'current': 1, 'next': 'https://www.google.com/search?q=LLM+orchestration&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=tsfcZ8DQKLuykvQPkMHtyQE&start=2&sa=N&ved=2ahUKEwjAg4yziZqMAxU7mYQIHZBgOxkQ8NMDegQIBRAW', 'other_pages': {'2': 'https://www.google.com/search?q=LLM+orchestration&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=tsfcZ8DQKLuykvQPkMHtyQE&start=2&sa=N&ved=2ahUKEwjAg4yziZqMAxU7mYQIHZBgOxkQ8tMDegQIBRAE', '3': 'https://www.google.com/search?q=LLM+orchestration&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=tsfcZ8DQKLuykvQPkMHtyQE&start=4&sa=N&ved=2ahUKEwjAg4yziZqMAxU7mYQIHZBgOxkQ8tMDegQIBRAG', '4': 'https://www.google.com/search?q=LLM+orchestration&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=tsfcZ8DQKLuykvQPkMHtyQE&start=6&sa=N&ved=2ahUKEwjAg4yziZqMAxU7mYQIHZBgOxkQ8tMDegQIBRAI', '5': 'https://www.google.com/search?q=LLM+orchestration&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=tsfcZ8DQKLuykvQPkMHtyQE&start=8&sa=N&ved=2ahUKEwjAg4yziZqMAxU7mYQIHZBgOxkQ8tMDegQIBRAK', '6': 'https://www.google.com/search?q=LLM+orchestration&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=tsfcZ8DQKLuykvQPkMHtyQE&start=10&sa=N&ved=2ahUKEwjAg4yziZqMAxU7mYQIHZBgOxkQ8tMDegQIBRAM', '7': 'https://www.google.com/search?q=LLM+orchestration&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=tsfcZ8DQKLuykvQPkMHtyQE&start=12&sa=N&ved=2ahUKEwjAg4yziZqMAxU7mYQIHZBgOxkQ8tMDegQIBRAO', '8': 'https://www.google.com/search?q=LLM+orchestration&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=tsfcZ8DQKLuykvQPkMHtyQE&start=14&sa=N&ved=2ahUKEwjAg4yziZqMAxU7mYQIHZBgOxkQ8tMDegQIBRAQ', '9': 'https://www.google.com/search?q=LLM+orchestration&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=tsfcZ8DQKLuykvQPkMHtyQE&start=16&sa=N&ved=2ahUKEwjAg4yziZqMAxU7mYQIHZBgOxkQ8tMDegQIBRAS', '10': 'https://www.google.com/search?q=LLM+orchestration&num=2&sca_esv=eeaec995fe4b7c04&tbm=nws&ei=tsfcZ8DQKLuykvQPkMHtyQE&start=18&sa=N&ved=2ahUKEwjAg4yziZqMAxU7mYQIHZBgOxkQ8tMDegQIBRAU'}}, 'serpapi_pagination': {'current': 1 ...
# 가져온 기사 수: 5
#
# --- [Article 1] ---
#
#
#
#
#
#
#
#
#
# Resources
#
#
# Blog
#
# Journalists
#
#
#
# Client Login
#
# Send a Release
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# News
#
#
# Products
#
#
# Contact
#
#
#
#
#
#
#
#
#               Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
# When typing in this field, a list of search results will appear and be automatically updated as you type.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sear
#
# --- [Article 2] ---
#
#
#
#
#
#
#
# Blog
# Themes
#
# Neve
# Hestia
# See All
#
#
# Plugins
#
# Feedzy RSS Feeds
# Otter Blocks
# See all
#
#
# About Us
# Help
#
# Docs
# Faq
# Contact
#
#
# Login
#
#
#
#
#
#
#
#
#
#
#
#
#
# My Journey to Creating a WordPress Plugin With ChatGPT: 120 Hours of Work, No Prior Experience
#
#
#
# Martin Dubovic
#
# Reviewed By:
#
# Karol K
#
# Updated on: Aug
#
# --- [Article 3] ---
# Skip to Main Content
#
#
#
#
# Search News & QuotesTopicsStock PicksLists & RankingsMagazineDataAdvisorAIStreet NotesAlphabet Is ‘Best Positioned’ as AI Agents Pose Risks to SearchBy Angela PalumboShareResizeReprintsIn this articleContinue reading this article with a Barron’s subscriptionSUBSCRIBE NOWTopi
#
# --- [Article 4] ---
#
# Skip to content
#
#
#
#
#
#
# 								Artificial Intelligence Computing Leadership from NVIDIA
#
#
#
#
#
#
#
#
#
#
#
# Search for:
#
#
#
#
#
#
#
#
#
#
# Toggle Search
#
#
#
#
#
#
#
#
#
#
#
#
# Home
# AI
# Data Center
# Driving
# Gaming
# Pro Graphics
# Robotics
# Healthcare
# Startups
# AI Podcast
# NVIDIA Life
#
#
#
#
#
#
#
#
#
#
#
# What Is Retrieval-Augmented Gene
#
# --- [Article 5] ---
#
#
#
#
# Events
# Video
# Special Issues
# Jobs
#
#
#
#
# VentureBeat Homepage
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Subscribe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Artificial Intelligence
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             View All
